# %% [markdown]
# # Processed Tournament Matchups Data
# Quick view of the training dataset for the NCAA tournament prediction model.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

df = pd.read_csv('../data/processed/tournament_matchups.csv')
print(f'Shape: {df.shape[0]} games, {df.shape[1]} columns')
print(f'Seasons: {sorted(df["season"].unique())}')
print(f'Home win rate: {df["home_win"].mean():.1%}')

# %%
# View the dataframe
df

# %%
# Column summary
print('All columns:')
for i, col in enumerate(df.columns):
    print(f'  {i+1:2d}. {col}')

# %%
# Basic stats
df.describe()
