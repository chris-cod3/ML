# %% [markdown]
# # NCAA Tournament Data Exploration
# Quick look at the collected DataFrames from our data sources.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.width', None)

# %% [markdown]
# ## Sports-Reference Combined Stats (2020)

# %%
sr_2020 = pd.read_csv('../data/raw/sportsref_combined_2020.csv')
print(f'Shape: {sr_2020.shape}')
sr_2020.head(20)

# %%
sr_2020.dtypes

# %%
sr_2020.describe()

# %% [markdown]
# ## Sports-Reference Combined Stats (2024)

# %%
sr_2024 = pd.read_csv('../data/raw/sportsref_combined_2024.csv')
print(f'Shape: {sr_2024.shape}')
sr_2024.head(20)

# %% [markdown]
# ## ESPN Tournament Games (2024)

# %%
tourney_2024 = pd.read_csv('../data/raw/espn_tournament_2024.csv')
print(f'Shape: {tourney_2024.shape}')
tourney_2024

# %%
tourney_2024.dtypes
